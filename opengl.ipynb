# %%
import OpenGL

# %%
dir(OpenGL)
# Out:
# ['ALLOW_NUMPY_SCALARS',
#  'ARRAY_SIZE_CHECKING',
#  'CONTEXT_CHECKING',
#  'ERROR_CHECKING',
#  'ERROR_LOGGING',
#  'ERROR_ON_COPY',
#  'FORWARD_COMPATIBLE_ONLY',
#  'FULL_LOGGING',
#  'FormatHandler',
#  'MODULE_ANNOTATIONS',
#  'PlatformPlugin',
#  'SIZE_1_ARRAY_UNPACK',
#  'STORE_POINTERS',
#  'UNSIGNED_BYTE_IMAGES_AS_STRING',
#  'USE_ACCELERATE',
#  'WARN_ON_FORMAT_UNAVAILABLE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_bi',
#  'environ_key',
#  'os',
#  'plugins',
#  'sys',
#  'version']

# %%
from OpenGL import GLUT

# %%
dir(GLUT)
# Out:
# ['ARRAY_TYPE_TO_CONSTANT',
#  'Constant',
#  'CurrentContextIsValid',
#  'FUNCTION_TYPE',
#  'GLDEBUGPROC',
#  'GLDEBUGPROCAMD',
#  'GLDEBUGPROCARB',
#  'GLDEBUGPROCKHR',
#  'GLUT',
#  'GLUTCallback',
#  'GLUTMenuCallback',
#  'GLUTTimerCallback',
#  'GLUT_3_2_CORE_PROFILE',
#  'GLUT_ACCUM',
#  'GLUT_ACTION_CONTINUE_EXECUTION',
#  'GLUT_ACTION_EXIT',
#  'GLUT_ACTION_GLUTMAINLOOP_RETURNS',
#  'GLUT_ACTION_ON_WINDOW_CLOSE',
#  'GLUT_ACTIVE_ALT',
#  'GLUT_ACTIVE_CTRL',
#  'GLUT_ACTIVE_SHIFT',
#  'GLUT_ALLOW_DIRECT_CONTEXT',
#  'GLUT_ALPHA',
#  'GLUT_API_VERSION',
#  'GLUT_AUX',
#  'GLUT_AUX1',
#  'GLUT_AUX2',
#  'GLUT_AUX3',
#  'GLUT_AUX4',
#  'GLUT_BITMAP_8_BY_13',
#  'GLUT_BITMAP_9_BY_15',
#  'GLUT_BITMAP_HELVETICA_10',
#  'GLUT_BITMAP_HELVETICA_12',
#  'GLUT_BITMAP_HELVETICA_18',
#  'GLUT_BITMAP_TIMES_ROMAN_10',
#  'GLUT_BITMAP_TIMES_ROMAN_24',
#  'GLUT_BLUE',
#  'GLUT_BORDERLESS',
#  'GLUT_CAPTIONLESS',
#  'GLUT_COMPATIBILITY_PROFILE',
#  'GLUT_CORE_PROFILE',
# ...

# %%
type(GLUT.GLUT_INIT_DISPLAY_MODE)
# Out:
# OpenGL.constant.IntConstant

# %%
print('\033')

# %%
from OpenGL import GL as gl

# %%
tuple(s for s in dir(gl) if '3' in s)
# Out:
# ('GL_3D',
#  'GL_3D_COLOR',
#  'GL_3D_COLOR_TEXTURE',
#  'GL_3_BYTES',
#  'GL_AUX3',
#  'GL_BOOL_VEC3',
#  'GL_C3F_V3F',
#  'GL_C4F_N3F_V3F',
#  'GL_C4UB_V3F',
#  'GL_CLIP_DISTANCE3',
#  'GL_CLIP_PLANE3',
#  'GL_COLOR_ATTACHMENT13',
#  'GL_COLOR_ATTACHMENT3',
#  'GL_DEPTH32F_STENCIL8',
#  'GL_DEPTH_COMPONENT32',
#  'GL_DEPTH_COMPONENT32F',
#  'GL_DOT3_RGB',
#  'GL_DOT3_RGBA',
#  'GL_DOUBLE_MAT2x3',
#  'GL_DOUBLE_MAT3',
#  'GL_DOUBLE_MAT3x2',
#  'GL_DOUBLE_MAT3x4',
#  'GL_DOUBLE_MAT4x3',
#  'GL_DOUBLE_VEC3',
#  'GL_DRAW_BUFFER13',
#  'GL_DRAW_BUFFER3',
#  'GL_FLOAT_32_UNSIGNED_INT_24_8_REV',
#  'GL_FLOAT_MAT2x3',
#  'GL_FLOAT_MAT3',
#  'GL_FLOAT_MAT3x2',
#  'GL_FLOAT_MAT3x4',
#  'GL_FLOAT_MAT4x3',
#  'GL_FLOAT_VEC3',
#  'GL_IMAGE_3D',
#  'GL_IMAGE_CLASS_1_X_32',
#  'GL_IMAGE_CLASS_2_X_32',
#  'GL_IMAGE_CLASS_4_X_32',
#  'GL_INT_IMAGE_3D',
#  'GL_INT_SAMPLER_3D',
#  'GL_INT_VEC3',
#  'GL_LIGHT3',
#  'GL_MAP1_TEXTURE_COORD_3',
#  'GL_MAP1_VERTEX_3',
#  'GL_MAP2_TEXTURE_COORD_3',
# ...

# %%
help(gl.GLfloat_3)
# Out:
# Help on class c_float_Array_3 in module OpenGL.raw.GL._types:
#
# class c_float_Array_3(_ctypes.Array)
#  |  Method resolution order:
#  |      c_float_Array_3
#  |      _ctypes.Array
#  |      _ctypes._CData
#  |      builtins.object
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _ctypes.Array:
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __new__(*args, **kwargs) from _ctypes.PyCArrayType
# ...
